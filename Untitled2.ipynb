# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

def load_and_accept_cookies():
        options = Options()
        driver = webdriver.Chrome(executable_path=r'C:\Users\vbamgbay\Downloads\chromedriver.exe', options=options)
        URL = "https://www.zoopla.co.uk/new-homes/property/london/?q=London&results_sort=newest_listings&search_source=new-homes&page_size=25&pn=1&view_type=list"
        driver.get(URL)
        
        accept_cookies = driver.find_elements_by_xpath('//*[@id="save"]/span[1]/div/span')
        for button in accept_cookies:
            if button.text == "Accept all cookies":
                relevant_button = button
                relevant_button.click()
        return driver
    
    
def get_properties(num_to_get=2):

    driver = load_and_accept_cookies()
    
    data = {"sale_price": [], "num_bedrooms": [], "sqft": [], "description": [], "address": []}    
    prop_container = driver.find_element_by_xpath('//*[@id="__next"]/div[5]/div[2]/main/div[2]/div[2]')
    properties = prop_container.find_elements_by_xpath('./div')
    num_props = len(properties)
    
    time.sleep(3)
    
    for i in range(num_props):
        prop_container = driver.find_element_by_xpath('//*[@id="__next"]/div[5]/div[2]/main/div[2]/div[2]')
        house = prop_container.find_elements_by_xpath('./div')[i]
        house.click()
        
        time.sleep(3)
        

        try:
            ## Find the price and append it to the dictionary
            price_elem = driver.find_elements_by_xpath('//*[@id="main-content"]/div[1]/div[1]/section[1]/div[1]/div[2]/span')
            data["sale_price"].append(price_elem.text)
        except:
            data["sale_price"].append(None)
        
        time.sleep(3)
        
        ## Find a link to click on
        house_page = driver.find_elements_by_xpath('//*[@id="__next"]/div[5]/div[2]/main/div[2]/div[3]/ul/li[2]/a')
        
        time.sleep(3)
        
        ## Find the number of bedrooms and append it to the dictionary
        ## HINT: https://lmgtfy.com/?q=xpath+svg+tag
        ## HINT: https://stackoverflow.com/questions/11657223/xpath-get-following-sibling
        try:
            bedrooms_elem = driver.find_element_by_xpath('//*[@id="main-content"]/div[1]/div[1]/section[1]/div[2]/div/div[1]/span')
            num_beds = bedrooms_elem.text[:-4] # " bedrooms" is 9 chars
        except:
            data["num_bedrooms"].append(num_beds)

        time.sleep(3)
            
        try:
            ## Find the number of square footage and append it to the dictionary
            sqft_elem = driver.find_element_by_xpath('//*[@id="main-content"]/div[1]/div[1]/section[1]/div[2]/div/div[4]/span')
            data["sqft"].append(sqft_elem.text)
        except:
            data["sqft"].append("None")

        time.sleep(3)
            
        ## Find the description and append it to the dictionary
        try:
            description_elem = driver.find_element_by_xpath('//*[@id="main-content"]/div[1]/section[3]/div[2]/div/div[1]/div/span')
            data["description"].append(description_elem.text)
        except:
            data["description"].append("None")
            
        time.sleep(3)
            
        ## Find the address
        try:
            address_elem = driver.find_element_by_xpath('//*[@id="listing-summary-details-heading"]/span[2]')
            data["address"].append(address_elem.text)
        except:
            data["address"].append("None")

        driver.execute_script("window.history.go(-1)")

    return data

properties = get_properties()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10212/2937225753.py in <module>
#      92     return data
#      93
# ---> 94 properties = get_properties()
#
# ~\AppData\Local\Temp/ipykernel_10212/2937225753.py in get_properties(num_to_get)
#      24
#      25     data = {"sale_price": [], "num_bedrooms": [], "sqft": [], "description": [], "address": []}
# ---> 26     prop_container = driver.find_element_by_xpath('//*[@id="__next"]/div[5]/div[2]/main/div[2]/div[2]')
#      27     properties = prop_container.find_elements_by_xpath('./div')
#      28     num_props = len(properties)
#
# ~\Miniconda3\envs\AiCore\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# ...

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.add_argument("start-maximized")
options.add_argument("--no-sandbox")
options.add_argument("--disable-setuid-sandbox")
driver = webdriver.Chrome(executable_path=r'C:\Users\vbamgbay\Downloads\chromedriver.exe', options=options)
URL = "https://www.youtube.com/c/aljazeeraenglish/videos"
driver.get(URL)

time.sleep(2)

#Consent
consent_div = driver.find_element_by_xpath('//button[@class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe DuMIQc IIdkle"]')
consent_span= consent_div.find_element_by_xpath('.//span')
consent_span.click()

time.sleep(3)

settings = driver.find_element_by_xpath('//div[@class="VP4fnf"]')
settings_list= driver.find_elements_by_xpath('//button')

for button in settings_list:
    if button.text == "On":
        button.click()
#        print(button)

time.sleep(5)

cookies_div = driver.find_element_by_xpath('//button[@class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe DuMIQc tVK8Qc"]')
cookies_span= cookies_div.find_element_by_xpath('.//span')
cookies_span.click()

time.sleep(3)

videos = driver.find_element_by_xpath('//div[@id="contents"]')
vid_list = container.find_elements_by_xpath('./div')
num_vids=len(vid_list)


for i in range(num_vids):
    videos = driver.find_element_by_xpath('//div[@class="css-1dbjc4n r-1jgb5lz r-1x0uki6 r-hvns9x r-ymttw5 r-13qz1uu"]')
    headline = container.find_elements_by_xpath('./div')[i]
    headline.click()
# Out:
# C:\Users\vbamgbay\AppData\Local\Temp/ipykernel_28296/3634718196.py:10: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=r'C:\Users\vbamgbay\Downloads\chromedriver.exe', chrome_options=options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28296/3634718196.py in <module>
#      15
#      16 consent_div = driver.find_element_by_xpath('//button[@class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe DuMIQc IIdkle"]')
# ---> 17 consent_span= cookies_div.find_element_by_xpath('.//span')
#      18 consent_span.click()
#      19
#
# ~\Miniconda3\envs\AiCore\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_xpath(self, xpath)
#     349             element = element.find_element_by_xpath('//div/td[1]')
#     350         """
# ...

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.add_argument("start-maximized")
options.add_argument("--no-sandbox")
options.add_argument("--disable-setuid-sandbox")
driver = webdriver.Chrome(executable_path=r'C:\Users\vbamgbay\Downloads\chromedriver.exe', options=options)
URL = "https://www.youtube.com/c/aljazeeraenglish/videos"
driver.get(URL)

time.sleep(2)

#Consent
consent_div = driver.find_element_by_xpath('//button[@class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe DuMIQc IIdkle"]')
consent_span= consent_div.find_element_by_xpath('.//span')
consent_span.click()

time.sleep(3)

settings = driver.find_element_by_xpath('//div[@class="VP4fnf"]')
settings_list= driver.find_elements_by_xpath('//button')

for button in settings_list:
    if button.text == "On":
        button.click()

time.sleep(3)

cookies_div = driver.find_element_by_xpath('//button[@class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe DuMIQc tVK8Qc"]')
cookies_span= cookies_div.find_element_by_xpath('.//span')
cookies_span.click()


time.sleep(3)

videos = driver.find_element_by_xpath('//div[@id="meta"]')
vid_list = videos.find_elements_by_xpath('./h')
num_vids=len(vid_list)
print(num_vids)

data = {"title":[], "description":[], "hash_tags":[], "comments":[], "no_likes":[], "no_dislikes":[]}

#time.sleep(3)

#for i in range(num_vids):
 #   videos = driver.find_element_by_xpath('//div[@id="items"]')
  #  headline = videos.find_elements_by_xpath('//a')[i]
   # headline.click()
    
#    title = driver.
#    description = driver.
#    hash_tags = driver.
#    comments = driver.
#    no_likes = driver.
#    no_dislikes = driver.   
    
#driver.back
# Out:
# 30

# %%
for button in relevant_button:
    print(button)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10212/3522159867.py in <module>
# ----> 1 for button in relevant_button:
#       2     print(button)
#
# TypeError: 'WebElement' object is not iterable

# %%
print((vid_list))
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="0999c873-bb4b-4cc1-95a0-e0cc8c07898c")>, <selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="c07e314d-b879-4d3b-b3c7-eacaf858b1b2")>, <selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="a21c7c9e-6271-4d3c-a321-ef987a7df03f")>, <selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="00332971-c176-49dc-a563-d0be00fd1467")>, <selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="20866f3e-70a8-495d-a717-aea0dca8a753")>, <selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="bedb7f30-3017-429e-bab3-df750267d870")>, <selenium.webdriver.remote.webelement.WebElement (session="1a4535a9b8c76fd6c2cf86dd16907c1d", element="50c07d37-bb50-4f87-a960-31d4fe
# ...
